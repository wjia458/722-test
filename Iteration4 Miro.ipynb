# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('airdata').getOrCreate()

# %%
air_data = spark.read.csv('i4/ChengduPM2013-2015.csv')

# %%
air_data.show() 
air_data.columns
# Out:
# +-----+----+-----+---+----+------+------------+----------+----------+----+-----+----+----+----+----+
# |  _c0| _c1|  _c2|_c3| _c4|   _c5|         _c6|       _c7|       _c8| _c9| _c10|_c11|_c12|_c13|_c14|
# +-----+----+-----+---+----+------+------------+----------+----------+----+-----+----+----+----+----+
# |   No|year|month|day|hour|season|PM_Caotangsi|PM_Shahepu|PM_US Post|DEWP| HUMI|PRES|TEMP|cbwd| Iws|
# |26305|2013|    1|  1|   0|     4|         121|       138|       129|  -4|64.42|1022|   2|  cv|   1|
# |26306|2013|    1|  1|   1|     4|         134|       159|       135|  -3|80.19|1022|   0|  cv|   1|
# |26307|2013|    1|  1|   2|     4|          NA|        NA|        55|  -3|80.19|1022|   0|  cv|   1|
# |26308|2013|    1|  1|   3|     4|         203|       162|        55|  -3|80.19|1022|   0|  SW|   1|
# |26309|2013|    1|  1|   4|     4|         217|       157|        55|  -1|  100|1021|  -1|  cv|   0|
# ...

# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('airdata').getOrCreate()

# %%
air_data = spark.read.csv('i4/ChengduPM2013-2015.csv')

# %%
air_data.na.drop().show()
# Out:
# +-----+----+-----+---+----+------+------------+----------+----------+----+-----+----+----+----+----+
# |  _c0| _c1|  _c2|_c3| _c4|   _c5|         _c6|       _c7|       _c8| _c9| _c10|_c11|_c12|_c13|_c14|
# +-----+----+-----+---+----+------+------------+----------+----------+----+-----+----+----+----+----+
# |   No|year|month|day|hour|season|PM_Caotangsi|PM_Shahepu|PM_US Post|DEWP| HUMI|PRES|TEMP|cbwd| Iws|
# |26305|2013|    1|  1|   0|     4|         121|       138|       129|  -4|64.42|1022|   2|  cv|   1|
# |26306|2013|    1|  1|   1|     4|         134|       159|       135|  -3|80.19|1022|   0|  cv|   1|
# |26307|2013|    1|  1|   2|     4|          NA|        NA|        55|  -3|80.19|1022|   0|  cv|   1|
# |26308|2013|    1|  1|   3|     4|         203|       162|        55|  -3|80.19|1022|   0|  SW|   1|
# |26309|2013|    1|  1|   4|     4|         217|       157|        55|  -1|  100|1021|  -1|  cv|   0|
# ...

# %%
# !pip install yellowbrick
# Out:
# /bin/sh: 1: pip: not found

# %%
import pandas as pd
import numpy as np
s1 = pd.read_csv("ChengduPM2013-2015.csv")
s2 = pd.read_csv("Chengdupre2013-2015.csv")
air_data = pd.concat([s1, s2])
print (air_data)
# Out:
#        DEWP    HUMI  Iprec  Iws       No  PM_Caotangsi  PM_Shahepu  \
# 0      -4.0   64.42    NaN  1.0  26305.0         121.0       138.0
# 1      -3.0   80.19    NaN  1.0  26306.0         134.0       159.0
# 2      -3.0   80.19    NaN  1.0  26307.0           NaN         NaN
# 3      -3.0   80.19    NaN  1.0  26308.0         203.0       162.0
# 4      -1.0  100.00    NaN  0.0  26309.0         217.0       157.0
# 5      -3.0   92.85    NaN  1.0  26310.0         220.0       170.0
# 6      -2.0   92.91    NaN  1.0  26311.0         214.0       225.0
# 7      -2.0  100.00    NaN  0.0  26312.0         209.0       244.0
# 8      -3.0  100.00    NaN  1.0  26313.0         228.0       242.0
# 9      -2.0  100.00    NaN  2.0  26314.0         219.0       277.0
# 10     -2.0   74.78    NaN  1.0  26315.0         225.0       281.0
# 11     -2.0   56.45    NaN  2.0  26316.0         192.0       284.0
# 12     -5.0   42.10    NaN  2.0  26317.0           NaN         NaN
# ...

# %%
air_data.head(n=10)
# Out:
#    DEWP    HUMI  Iprec  Iws       No  PM_Caotangsi  PM_Shahepu  PM_US Post  \
# 0  -4.0   64.42    NaN  1.0  26305.0         121.0       138.0       129.0
# 1  -3.0   80.19    NaN  1.0  26306.0         134.0       159.0       135.0
# 2  -3.0   80.19    NaN  1.0  26307.0           NaN         NaN        55.0
# 3  -3.0   80.19    NaN  1.0  26308.0         203.0       162.0        55.0
# 4  -1.0  100.00    NaN  0.0  26309.0         217.0       157.0        55.0
# 5  -3.0   92.85    NaN  1.0  26310.0         220.0       170.0        55.0
# 6  -2.0   92.91    NaN  1.0  26311.0         214.0       225.0        55.0
# 7  -2.0  100.00    NaN  0.0  26312.0         209.0       244.0        55.0
# 8  -3.0  100.00    NaN  1.0  26313.0         228.0       242.0        55.0
# 9  -2.0  100.00    NaN  2.0  26314.0         219.0       277.0        55.0
#
#      PRES  TEMP cbwd  day  hour  month  precipitation  season    year
# 0  1022.0   2.0   cv  1.0   0.0    1.0            NaN     4.0  2013.0
# ...

# %%
air_data.tail(n=5)
# Out:
#        DEWP  HUMI  Iprec  Iws  No  PM_Caotangsi  PM_Shahepu  PM_US Post  PRES  \
# 26275   NaN   NaN    0.0  NaN NaN           NaN         NaN         NaN   NaN
# 26276   NaN   NaN    0.0  NaN NaN           NaN         NaN         NaN   NaN
# 26277   NaN   NaN    0.0  NaN NaN           NaN         NaN         NaN   NaN
# 26278   NaN   NaN    0.0  NaN NaN           NaN         NaN         NaN   NaN
# 26279   NaN   NaN    0.0  NaN NaN           NaN         NaN         NaN   NaN
#
#        TEMP cbwd  day  hour  month  precipitation  season  year
# 26275   NaN  NaN  NaN   NaN    NaN            0.0     NaN   NaN
# 26276   NaN  NaN  NaN   NaN    NaN            0.0     NaN   NaN
# 26277   NaN  NaN  NaN   NaN    NaN            0.0     NaN   NaN
# 26278   NaN  NaN  NaN   NaN    NaN            0.0     NaN   NaN
# 26279   NaN  NaN  NaN   NaN    NaN            0.0     NaN   NaN

# %%
air_data.info
# Out:
# <bound method DataFrame.info of        DEWP    HUMI  Iprec  Iws       No  PM_Caotangsi  PM_Shahepu  \
# 0      -4.0   64.42    NaN  1.0  26305.0         121.0       138.0
# 1      -3.0   80.19    NaN  1.0  26306.0         134.0       159.0
# 2      -3.0   80.19    NaN  1.0  26307.0           NaN         NaN
# 3      -3.0   80.19    NaN  1.0  26308.0         203.0       162.0
# 4      -1.0  100.00    NaN  0.0  26309.0         217.0       157.0
# 5      -3.0   92.85    NaN  1.0  26310.0         220.0       170.0
# 6      -2.0   92.91    NaN  1.0  26311.0         214.0       225.0
# 7      -2.0  100.00    NaN  0.0  26312.0         209.0       244.0
# 8      -3.0  100.00    NaN  1.0  26313.0         228.0       242.0
# 9      -2.0  100.00    NaN  2.0  26314.0         219.0       277.0
# 10     -2.0   74.78    NaN  1.0  26315.0         225.0       281.0
# 11     -2.0   56.45    NaN  2.0  26316.0         192.0       284.0
# ...

# %%
air_data.isnull().sum().sort_values(ascending=False)
# Out:
# PM_Caotangsi     28140
# PM_Shahepu       27966
# precipitation    27372
# Iprec            27372
# Iws              26775
# HUMI             26769
# DEWP             26767
# TEMP             26765
# PRES             26763
# cbwd             26763
# PM_US Post       26280
# season           26280
# No               26280
# day              26280
# hour             26280
# month            26280
# year             26280
# dtype: int64

# %%
air_data.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [DEWP, HUMI, Iprec, Iws, No, PM_Caotangsi, PM_Shahepu, PM_US Post, PRES, TEMP, cbwd, day, hour, month, precipitation, season, year]
# Index: []

# %%
air_data.PM_Caotangsi = air_data.PM_Caotangsi.fillna(air_data.PM_Caotangsi.mean())
air_data.PM_Shahepu = air_data.PM_Shahepu.fillna(air_data.PM_Shahepu.mean())

# %%
print(air_data.Iprec.fillna(method='ffill'))
print(air_data.precipitation.fillna(method='ffill'))
print(air_data.Iws.fillna(method='ffill'))
print(air_data.HUMI.fillna(method='ffill'))
print(air_data.DEWP.fillna(method='ffill'))
print(air_data.TEMP.fillna(method='ffill'))
print(air_data.cbwd.fillna(method='ffill'))
print(air_data.PRES.fillna(method='ffill'))
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#         ...
# 26250    0.0
# 26251    0.0
# 26252    0.0
# 26253    0.0
# 26254    0.0
# 26255    0.0
# 26256    0.0
# 26257    0.0
# 26258    0.0
# 26259    0.0
# 26260    0.0
# 26261    0.0
# 26262    0.0
# 26263    0.0
# 26264    0.0
# 26265    0.0
# 26266    0.0
# 26267    0.0
# 26268    0.0
# 26269    0.0
# 26270    0.0
# 26271    0.0
# 26272    0.0
# 26273    0.0
# 26274    0.0
# 26275    0.0
# 26276    0.0
# 26277    0.0
# 26278    0.0
# 26279    0.0
# Name: Iprec, Length: 52560, dtype: float64
# 0        NaN
# 1        NaN
# ...

# %%
air_data.Iprec=air_data.Iprec.fillna(method='ffill')
air_data.precipitation=air_data.precipitation.fillna(method='ffill')
air_data.Iws=air_data.Iws.fillna(method='ffill')
air_data.HUMI=air_data.HUMI.fillna(method='ffill')
air_data.DEWP=air_data.DEWP.fillna(method='ffill')
air_data.TEMP=air_data.TEMP.fillna(method='ffill')
air_data.cbwd=air_data.cbwd.fillna(method='ffill')
air_data.PRES=air_data.PRES.fillna(method='ffill')

# %%
air_data.isnull().sum().sort_values(ascending=False)
# Out:
# year             26280
# No               26280
# precipitation    26280
# month            26280
# hour             26280
# day              26280
# Iprec            26280
# season           26280
# PM_US Post       26280
# HUMI                 0
# Iws                  0
# PRES                 0
# PM_Caotangsi         0
# PM_Shahepu           0
# TEMP                 0
# cbwd                 0
# DEWP                 0
# dtype: int64

# %%
air_data.dtypes
# Out:
# DEWP             float64
# HUMI             float64
# Iprec            float64
# Iws              float64
# No               float64
# PM_Caotangsi     float64
# PM_Shahepu       float64
# PM_US Post       float64
# PRES             float64
# TEMP             float64
# cbwd              object
# day              float64
# hour             float64
# month            float64
# precipitation    float64
# season           float64
# year             float64
# dtype: object

# %%
air_data['PM_US Post'] = air_data['PM_US Post'].astype('object')
air_data['PM_Caotangsi'] = air_data['PM_Caotangsi'].astype('object')
air_data['PM_Shahepu'] = air_data['PM_Shahepu'].astype('object')

# %%
air_data.dtypes
# Out:
# DEWP             float64
# HUMI             float64
# Iprec            float64
# Iws              float64
# No               float64
# PM_Caotangsi      object
# PM_Shahepu        object
# PM_US Post        object
# PRES             float64
# TEMP             float64
# cbwd              object
# day              float64
# hour             float64
# month            float64
# precipitation    float64
# season           float64
# year             float64
# dtype: object

# %%
air_data['PM_US Post'] = air_data['PM_US Post'].astype('object')
air_data['PM_Caotangsi'] = air_data['PM_Caotangsi'].astype('object')
air_data['PM_Shahepu'] = air_data['PM_Shahepu'].astype('object')

# %%
air_data.dtypes
# Out:
# DEWP             float64
# HUMI             float64
# Iprec            float64
# Iws              float64
# No               float64
# PM_Caotangsi      object
# PM_Shahepu        object
# PM_US Post        object
# PRES             float64
# TEMP             float64
# cbwd              object
# day              float64
# hour             float64
# month            float64
# precipitation    float64
# season           float64
# year             float64
# dtype: object

# %%
air_data.corr()["season"]
# Out:
# DEWP            -4.473855e-01
# HUMI             2.090256e-01
# Iprec                     NaN
# Iws             -1.667626e-01
# No               7.043939e-02
# PRES             5.328503e-01
# TEMP            -5.793632e-01
# day             -1.365995e-02
# hour            -1.748755e-20
# month            2.076551e-01
# precipitation             NaN
# season           1.000000e+00
# year             4.077093e-18
# Name: season, dtype: float64

# %%
subair_data1=air_data[["season","year","PM_US Post","PM_Caotangsi","PM_Shahepu","TEMP"]]

# %%
subair_data1.shape
# Out:
# (52560, 6)

# %%
subair_data1.head(n=5)
# Out:
#    season    year PM_US Post PM_Caotangsi PM_Shahepu  TEMP
# 0     4.0  2013.0        129          121        138   2.0
# 1     4.0  2013.0        135          134        159   0.0
# 2     4.0  2013.0         55       77.507    75.5559   0.0
# 3     4.0  2013.0         55          203        162   0.0
# 4     4.0  2013.0         55          217        157  -1.0

# %%
data = subair_data1
target = subair_data1['PM_Caotangsi']
data.head(n=2)
# Out:
#    season    year PM_US Post PM_Caotangsi PM_Shahepu  TEMP
# 0     4.0  2013.0        129          121        138   2.0
# 1     4.0  2013.0        135          134        159   0.0

# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import *
spark = SparkSession.builder.appName('airdata_logistics').getOrCreate()
from pyspark.ml.classification import LogisticRegression

# %%
airdata = spark.read.csv('ChengduPM2013-2015.csv',inferSchema=True,header=True)

# %%
airdata.printSchema()
airdata.columns
# Out:
# root
#  |-- No: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- season: integer (nullable = true)
#  |-- PM_Caotangsi: string (nullable = true)
#  |-- PM_Shahepu: string (nullable = true)
#  |-- PM_US Post: integer (nullable = true)
#  |-- DEWP: string (nullable = true)
#  |-- HUMI: string (nullable = true)
#  |-- PRES: string (nullable = true)
#  |-- TEMP: string (nullable = true)
#  |-- cbwd: string (nullable = true)
#  |-- Iws: string (nullable = true)
# ['No',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'season',
#  'PM_Caotangsi',
#  'PM_Shahepu',
#  'PM_US Post',
#  'DEWP',
#  'HUMI',
#  'PRES',
#  'TEMP',
#  'cbwd',
#  'Iws']

# %%
air_cols = airdata.select(['season',
 'year',
 'PM_Caotangsi',
 'PM_Shahepu',
 'PM_US Post',
 'TEMP'])

# %%
from pyspark.ml.feature import (VectorAssembler,VectorIndexer,
                                OneHotEncoder,StringIndexer)

# %%
from pyspark.ml.classification import LogisticRegression

# %%
from pyspark.ml import Pipeline

# %%
season_indexer = StringIndexer(inputCol='PM_Caotangsi',outputCol='CaotangxiIndex')
embark_encoder = OneHotEncoder(inputCol='PM_Shahepu',outputCol='ShahepuVec')

# %%
pipeline = Pipeline(stages=[season_indexer,embark_encoder,log_reg_titanic])

# %%
log_reg_titanic = LogisticRegression(featuresCol='feature',labelCol='PM_Caotangsi')

# %%
my_final_data = my_cols.na.drop()

# %%
train_titanic_data, test_titanic_data = my_final_data.randomSplit([0.7,.3])

# %%
fit_model = pipeline.fit(train_titanic_data)

# %%
results = fit_model.transform(test_titanic_data)

# %%
results = airdata

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

my_eval = BinaryClassificationEvaluator(rawPredictionCol='prediction',
                                       labelCol='PM_Caotangsi')

# %%
results.select('season','TEMP').show()
# Out:
# +------+----+
# |season|TEMP|
# +------+----+
# |     4|   2|
# |     4|   0|
# |     4|   0|
# |     4|   0|
# |     4|  -1|
# |     4|  -2|
# |     4|  -1|
# |     4|  -2|
# |     4|  -3|
# |     4|  -2|
# |     4|   2|
# |     4|   6|
# |     4|   7|
# |     4|   9|
# |     4|  10|
# |     4|  10|
# |     4|  10|
# |     4|  10|
# |     4|   7|
# |     4|   4|
# +------+----+
# only showing top 20 rows

# %%
AUC = my_eval.evaluate(results)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~/spark-2.1.1-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~/spark-2.1.1-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#
# Py4JJavaError: An error occurred while calling o1023.evaluate.
# : java.lang.IllegalArgumentException: Field "prediction" does not exist.
# 	at org.apache.spark.sql.types.StructType$$anonfun$apply$1.apply(StructType.scala:264)
# 	at org.apache.spark.sql.types.StructType$$anonfun$apply$1.apply(StructType.scala:264)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
sexArr = np.array(data.select('season').collect())
plt.hist(sexArr)
plt.show()

# Because you can interact with Spark using SQL, you can also filter the data you see. 
# For example, age has some null values. We can remove all null values before visualising the data.
ageArr = np.array(data.filter('PM_Caotangsi > 150').select('PM_Caotangsi').collect())
plt.hist(ageArr)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
hist = airdata.select("season").rdd.flatMap(lambda x: x).histogram(20)

# %%
airdata = {"bins":hist[0][:-1],"freq":hist[1]}
plt.bar(airdata["bins"],airdata["freq"],width=2000)
plt.xlabel("PM_Caotangsi")
plt.ylabel("season")
plt.title("year-pm2.5")
# Out:
# Text(0.5,1,'year-pm2.5')

# %%
data_multi ={airdata.select(season).rdd.flatMap(lambda x:x).collect()\
             for season in ["balance","numTrans","numIntlTrans"]}
plt.scatter(airdata["numTrans"],airdata["balance"],c ='r',marker='o',label="numTrans-balance")
plt.scatter(airdata["numIntlTrans"],airdata["balance"],c ='b',marker="x",label="numInt-balance")
plt.grid(True)
plt.xlabel("PM_Caotangsi")
plt.ylabel("season")
plt.legend(loc='upper right')#图例的位置
plt.title("view")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-24d19bd2b361> in <module>()
# ----> 1 data_multi ={airdata.select(season).rdd.flatMap(lambda x:x).collect()             for season in ["balance","numTrans","numIntlTrans"]}
#       2 plt.scatter(airdata["numTrans"],airdata["balance"],c ='r',marker='o',label="numTrans-balance")
#       3 plt.scatter(airdata["numIntlTrans"],airdata["balance"],c ='b',marker="x",label="numInt-balance")
#       4 plt.grid(True)
#       5 plt.xlabel("PM_Caotangsi")
#
# <ipython-input-21-24d19bd2b361> in <setcomp>(.0)
# ----> 1 data_multi ={airdata.select(season).rdd.flatMap(lambda x:x).collect()             for season in ["balance","numTrans","numIntlTrans"]}
#       2 plt.scatter(airdata["numTrans"],airdata["balance"],c ='r',marker='o',label="numTrans-balance")
# ...
